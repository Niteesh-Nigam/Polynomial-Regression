# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
data = np.loadtxt('./dataset.txt')
# print(data)
features = data.shape[1]-1
# print(features)
X_train = np.array(data[:,:features])
print(X_train.shape)
y_train = np.array(data[:,-1])
# Out:
# (506, 13)

# %%
PolyF = PolynomialFeatures(degree = 2)
X_PolyF = PolyF.fit_transform(X_train)
print(f"Peak to Peak range by column in Raw        X:{np.ptp(X_train,axis=0)}")   
print(f"Peak to Peak range by column in Normalized X:{np.ptp(X_PolyF,axis=0)}")
# Out:
# Peak to Peak range by column in Raw        X:[8.896988e+01 1.000000e+02 2.728000e+01 1.000000e+00 4.860000e-01
#  5.219000e+00 9.710000e+01 1.099690e+01 2.300000e+01 5.240000e+02
#  9.400000e+00 3.965800e+02 3.624000e+01]
# Peak to Peak range by column in Normalized X:[0.00000000e+00 8.89698800e+01 1.00000000e+02 2.72800000e+01
#  1.00000000e+00 4.86000000e-01 5.21900000e+00 9.71000000e+01
#  1.09969000e+01 2.30000000e+01 5.24000000e+02 9.40000000e+00
#  3.96580000e+02 3.62400000e+01 7.91676413e+03 1.65052000e+01
#  1.61046287e+03 8.98296000e+00 5.96996300e+01 6.19944608e+02
#  8.17672433e+03 1.32526720e+02 2.13542248e+03 5.92562785e+04
#  1.79722254e+03 3.53125041e+04 1.69165930e+03 1.00000000e+04
#  4.21120000e+02 9.00000000e+01 4.11000000e+01 7.63230000e+02
#  4.05000000e+03 1.09138500e+03 5.00000000e+02 3.81900000e+04
#  1.76000000e+03 3.92900000e+04 1.11000000e+03 7.69296000e+02
#  1.95800000e+01 1.68600600e+01 1.62345920e+02 2.72599200e+03
#  8.53761360e+01 4.33190000e+02 1.96058400e+04 5.50950000e+02
#  1.10042140e+04 8.21957000e+02 1.00000000e+00 8.71000000e-01
#  8.78000000e+00 1.00000000e+02 5.88500000e+00 2.40000000e+01
#  6.66000000e+02 2.02000000e+01 3.96900000e+02 2.68200000e+01
#  6.10416000e-01 4.01609400e+00 8.58008000e+01 4.23416290e+00
#  1.80950000e+01 4.36150000e+02 1.04636000e+01 3.45471740e+02
#  2.48731900e+01 6.44076790e+01 7.66779500e+02 7.68821860e+01
#  2.05014000e+02 4.79223600e+03 1.05423800e+02 3.38978912e+03
#  1.88952730e+02 9.99159000e+03 6.21404990e+02 2.39130000e+03
#  6.95711000e+04 2.06809000e+03 3.96603680e+04 3.78296400e+03
#  1.45776006e+02 9.61917000e+01 4.07157970e+03 2.13457880e+02
#  4.66141064e+03 1.78627596e+02 5.75000000e+02 1.57860000e+04
#  4.71200000e+02 9.51792000e+03 9.08120000e+02 4.70552000e+05
#  1.15983000e+04 2.81982780e+05 2.47890600e+04 3.25240000e+02
#  8.41513600e+03 7.41563000e+02 1.57529508e+05 1.50647122e+04
#  1.43872800e+03]

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(X_PolyF)
print(f"Peak to Peak range by column in Raw        X:{np.ptp(X_PolyF,axis=0)}")   
print(f"Peak to Peak range by column in Normalized X:{np.ptp(X_norm,axis=0)}")
# Out:
# Peak to Peak range by column in Raw        X:[0.00000000e+00 8.89698800e+01 1.00000000e+02 2.72800000e+01
#   3.7695958   5.7698909   6.10073738]

# %%
lmr = LinearRegression()
lmr.fit(X_norm, y_train)
print(lmr)
# Out:
# LinearRegression()

# %%
b_norm = lmr.intercept_
w_norm = lmr.coef_
print(f"model parameters:                   w: {w_norm}, b:{b_norm}")
# Out:
# model parameters:                   w: [ 1.72922481e+13 -4.04954067e+01  9.02719899e+00 -3.78586110e+01
#   8.93770098e+00  1.64574462e+01  1.29805766e+01  1.89581587e+01
#  -1.12844711e+01  3.29961329e+01  3.13048762e-01  9.93391165e+00
#   7.65243899e+00 -3.98308558e-01  7.56484495e-01  6.53129452e-01
#   6.21229772e+01  1.82067642e+00 -4.07283789e+00  5.96405392e+00
#  -1.49781094e+00 -2.53738209e-01  4.73581822e+01 -1.40330962e+02
#   6.58659105e+01 -4.48598025e-01  3.90911527e+00  9.60803166e-02
#  -4.87566890e-01 -5.02790522e-01 -1.19278233e+01  1.47096746e+00
#   7.83009808e-01 -3.76097123e+00 -9.71132463e-01  3.53434696e+00
#   3.50971957e-01  2.74725752e+00 -1.21493386e+00  4.63237747e+00
#   2.97913443e-01  1.03227538e+01  1.14252658e+01  6.16248574e+00
#   2.65169186e+00 -3.25692930e+00  3.75969080e+00 -3.91964480e+00
#   8.27449075e+00  1.16151570e-01  8.93770098e+00 -6.28927791e+00
#  -6.46110703e+00 -2.27199308e+00 -1.14807028e-01  2.25478310e-01
#   3.14108635e-01 -4.21345783e+00 -5.19245278e-01  3.47347378e-01
#  -4.88171726e+00 -5.72215945e-01 -9.83269037e+00  8.78999159e+00
#  -6.26239408e+00  8.29124673e+00 -2.21121055e+01 -7.48648889e-01
#   5.55014779e+00  3.08742437e+00 -6.72913371e+00 -1.02135182e+00
#  -1.02475386e+01 -1.25686070e+01 -6.02787350e+00 -2.48793695e+00
#  -7.08690791e+00  6.21111601e-01 -3.25747950e-01  1.21152927e+01
#  -6.62257653e+00 -1.16979109e-01 -6.88703011e+00 -7.67146117e+00
#   1.03927071e+01 -1.92481652e+00 -1.49596164e+00 -7.55931151e+00
#  -4.66940224e+00  2.01187279e+00 -3.55111748e+01  5.36042158e+01
#  -2.45031522e+01  2.87741317e-01 -9.49232654e+00 -1.11698645e+01
#   2.23333868e+01 -7.97305730e+00 -2.38350574e-01 -3.54369694e-02
#   5.39935774e+00  5.59347391e+00 -1.26884053e+00 -1.17266658e+00
#   3.83207918e+00], b:22.532806324110755

# %%
y_pred_sgd = lmr.predict(X_norm)
print(f"Prediction on training set:\n{y_pred_sgd[:4]}" )
print(f"Target values \n{y_train[:4]}")
# Out:
# Prediction on training set:
# [23.77421515 22.14420215 32.2203748  31.58193915]
# Target values
# [24.  21.6 34.7 33.4]

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 5), sharey=True)

# Assuming the number of features is less than or equal to 9 for this grid
for i in range(3):  # Rows
    for j in range(3):  # Columns
        feature_index = i * 3 + j
        if feature_index < features:
            ax[i, j].scatter(X_train[:, feature_index], y_train, label='Target', c='r')
            ax[i, j].scatter(X_train[:, feature_index], y_pred_sgd, label='Predict', c='b')
            ax[i, j].set_title(f"Feature {feature_index + 1}")
            ax[i, j].legend()

plt.show()
